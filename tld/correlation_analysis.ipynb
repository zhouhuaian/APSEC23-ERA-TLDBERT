# %%
import scipy.stats as stats
from pathlib import Path
import json
import numpy as np
from sklearn.metrics import classification_report
import pandas as pd

# Link type map
from model.linktypes import fine_linktype_map

# %%
res_dir = Path.cwd() / 'data' / 'results' / 'bert-base-uncased'

REPOS = []
cls_rep_d = {}

for run_dir in res_dir.iterdir():
    run_name = run_dir.name
    
    if 'linktype' in (run_name.split('_')) and 'plus' in (run_name.split('_')):
        repo = run_name.split('_')[0]
        print(repo)
        REPOS.append(repo)
        
        with (run_dir / 'run_config.json').open('r', encoding='utf8') as f:
            run_config = json.load(f)
        test_output = np.load(run_dir / 'test_output.npz')
        
        cls_rep = classification_report(
            test_output['labels'],
            test_output['logits'].argmax(axis=-1),
            target_names=run_config['label_names'],
            output_dict=True
        )
        
        cls_rep_df = pd.DataFrame(cls_rep).transpose()
        cls_rep_df.to_csv(run_dir / (repo + '_LT_plus_cls_report.csv'))
        
        cls_rep_d[repo] = cls_rep_df
# Out:
# JFrog
# Sakai
# Hyperledger
# MariaDB
# Jira
# MongoDB
# Apache
# Mojang
# Spring
# Qt
# JiraEcosystem
# IntelDAOS
# RedHat
# SecondLife
# Sonatype

# %%
tldbert_res_dir = Path.cwd() / 'data' / 'results' / 'tldbert'

tb_cls_rep_d = {}

for run_dir in tldbert_res_dir.iterdir():
    run_name = run_dir.name
    
    if 'linktype' in (run_name.split('_')) and 'plus' in (run_name.split('_')):
        repo = run_name.split('_')[0]
        print(repo)
        
        with (run_dir / 'run_config.json').open('r', encoding='utf8') as f:
            run_config = json.load(f)
        test_output = np.load(run_dir / 'test_output.npz')
        
        cls_rep = classification_report(
            test_output['labels'],
            test_output['logits'].argmax(axis=-1),
            target_names=run_config['label_names'],
            output_dict=True
        )
        
        cls_rep_df = pd.DataFrame(cls_rep).transpose()
        cls_rep_df.to_csv(run_dir / (repo + '_LT_plus_cls_report.csv'))
        
        tb_cls_rep_d[repo] = cls_rep_df
# Out:
# JFrog
# IntelDAOS
# Hyperledger
# Mojang
# MariaDB
# JiraEcosystem
# Spring
# Sonatype
# SecondLife
# Jira
# RedHat
# Apache
# Sakai
# MongoDB
# Qt

# %%
# Sort repos alphabetically
REPOS.sort()
REPOS
# Out:
# ['Apache',
#  'Hyperledger',
#  'IntelDAOS',
#  'JFrog',
#  'Jira',
#  'JiraEcosystem',
#  'MariaDB',
#  'Mojang',
#  'MongoDB',
#  'Qt',
#  'RedHat',
#  'Sakai',
#  'SecondLife',
#  'Sonatype',
#  'Spring']

# %%
for repo in REPOS:
    beta = np.round(cls_rep_d[repo]['support'].loc['macro avg'] / cls_rep_d[repo]['support'], 0) ** 2
    pre = cls_rep_d[repo]['precision']
    rec = cls_rep_d[repo]['recall']
    cls_rep_d[repo]['fbeta-score'] = (1 + beta) * (pre * rec) / ((beta * pre) + rec)
    cls_rep_d[repo]['fbeta-score'].fillna(0, inplace=True)

    tb_beta = np.round(tb_cls_rep_d[repo]['support'].loc['macro avg'] / tb_cls_rep_d[repo]['support'], 0) ** 2
    tb_pre = tb_cls_rep_d[repo]['precision']
    tb_rec = tb_cls_rep_d[repo]['recall']
    tb_cls_rep_d[repo]['fbeta-score'] = (1 + tb_beta) * (tb_pre * tb_rec) / ((tb_beta * tb_pre) + tb_rec)
    tb_cls_rep_d[repo]['fbeta-score'].fillna(0, inplace=True)

# %%
print('TLD results of BERT')
for repo in REPOS:
    print(repo)
    print('-------------------------------')
    print(cls_rep_d[repo])
    print('-------------------------------\n')
# Out:
# TLD results of BERT
# Apache
# -------------------------------
#               precision    recall  f1-score       support  fbeta-score
# Subtask        0.892710  0.928030  0.910027  16757.000000     0.924373
# Relate         0.591191  0.704126  0.642735  14469.000000     0.696302
# Duplicate      0.557914  0.420829  0.479771   5185.000000     0.421856
# Block          0.529252  0.475130  0.500733   2875.000000     0.475280
# Epic           0.955364  0.975610  0.965381   2501.000000     0.975563
# Depend         0.539989  0.402400  0.461151   2500.000000     0.402632
# Non-Link       0.766384  0.739355  0.752627   2325.000000     0.739404
# Incorporate    0.589456  0.503594  0.543152   2087.000000     0.503711
# Breaks         0.352795  0.326437  0.339104    870.000000     0.326444
# Clone          0.677650  0.547454  0.605634    864.000000     0.547482
# Require        0.528509  0.332873  0.408475    724.000000     0.332897
# Supercede      0.366834  0.224615  0.278626    650.000000     0.224629
# Cause          0.366460  0.285024  0.320652    621.000000     0.285033
# accuracy       0.702373  0.702373  0.702373      0.702373     0.702373
# macro avg      0.593424  0.528114  0.554467  52428.000000     0.558867
# weighted avg   0.694665  0.702373  0.694691  52428.000000     0.698498
# -------------------------------
#
# Hyperledger
# -------------------------------
#               precision    recall  f1-score      support  fbeta-score
# Epic           0.958584  0.985294  0.971756  1292.000000     0.982556
# Subtask        0.886564  0.895439  0.890980   899.000000     0.894912
# Relate         0.654854  0.757576  0.702479   561.000000     0.755206
# Non-Link       0.860590  0.786765  0.822023   408.000000     0.787589
# Block          0.662281  0.561338  0.607646   269.000000     0.561773
# Duplicate      0.485714  0.265625  0.343434   128.000000     0.265768
# Clone          0.781250  0.789474  0.785340    95.000000     0.789468
# accuracy       0.844469  0.844469  0.844469     0.844469     0.844469
# macro avg      0.755691  0.720216  0.731951  3652.000000     0.737527
# weighted avg   0.840238  0.844469  0.840087  3652.000000     0.842348
# -------------------------------
#
# IntelDAOS
# -------------------------------
#               precision    recall  f1-score     support  fbeta-score
# Relate         0.668342  0.655172  0.661692  203.000000     0.656466
# Block          0.636364  0.684211  0.659420  133.000000     0.681198
# Subtask        0.811321  0.781818  0.796296   55.000000     0.782100
# Duplicate      0.344262  0.420000  0.378378   50.000000     0.419244
# Clone          0.791667  0.883721  0.835165   43.000000     0.883117
# Non-Link       0.678571  0.475000  0.558824   40.000000     0.475724
# finish-start   0.846154  0.550000  0.666667   20.000000     0.550245
# Verify         1.000000  0.875000  0.933333    8.000000     0.875023
# accuracy       0.657609  0.657609  0.657609    0.657609     0.657609
# macro avg      0.722085  0.665615  0.686222  552.000000     0.692701
# weighted avg   0.667125  0.657609  0.659070  552.000000     0.662333
# -------------------------------
#
# JFrog
# -------------------------------
#               precision    recall  f1-score     support  fbeta-score
# Subtask        0.923729  0.935622  0.929638  233.000000     0.934419
# Relate         0.548223  0.610169  0.577540  177.000000     0.606141
# Duplicate      0.555556  0.465116  0.506329  129.000000     0.468047
# Non-Link       0.906977  0.661017  0.764706   59.000000     0.662256
# Depend         0.372549  0.372549  0.372549   51.000000     0.372549
# Trigger        0.132075  0.175000  0.150538   40.000000     0.174804
# Incorporate    0.100000  0.111111  0.105263    9.000000     0.111109
# accuracy       0.647564  0.647564  0.647564    0.647564     0.647564
# macro avg      0.505587  0.475798  0.486652  698.000000     0.490240
# weighted avg   0.662787  0.647564  0.652196  698.000000     0.655088
# -------------------------------
#
# Jira
# -------------------------------
#               precision    recall  f1-score       support  fbeta-score
# Relate         0.845723  0.916811  0.879834  12682.000000     0.901653
# Duplicate      0.747980  0.660377  0.701454   4346.000000     0.663366
# Non-Link       0.890928  0.830798  0.859813   1052.000000     0.830953
# Clone          0.655102  0.560209  0.603951    573.000000     0.560272
# Subtask        0.953878  0.919192  0.936214    495.000000     0.919212
# Incorporate    0.785714  0.537678  0.638452    491.000000     0.537779
# Detail         0.887283  0.820856  0.852778    374.000000     0.820877
# Cause          0.574194  0.249300  0.347656    357.000000     0.249343
# accuracy       0.825086  0.825086  0.825086      0.825086     0.825086
# macro avg      0.792600  0.686903  0.727519  20370.000000     0.735976
# weighted avg   0.819028  0.825086  0.818710  20370.000000     0.822046
# -------------------------------
#
# JiraEcosystem
# -------------------------------
#               precision    recall  f1-score      support  fbeta-score
# Epic           0.957895  0.994536  0.975871   549.000000     0.992303
# Relate         0.618026  0.550669  0.582406   523.000000     0.554222
# Subtask        0.858012  0.925602  0.890526   457.000000     0.922806
# Duplicate      0.556675  0.635057  0.593289   348.000000     0.633274
# Block          0.477876  0.400000  0.435484   135.000000     0.400225
# Non-Link       0.663366  0.587719  0.623256   114.000000     0.587871
# Cause          0.355140  0.431818  0.389744    88.000000     0.431691
# Incorporate    0.458333  0.268293  0.338462    41.000000     0.268327
# Clone          0.609756  0.625000  0.617284    40.000000     0.624996
# Depend         0.200000  0.160000  0.177778    25.000000     0.160004
# Split          0.416667  0.208333  0.277778    24.000000     0.208344
# accuracy       0.717577  0.717577  0.717577     0.717577     0.717577
# macro avg      0.561068  0.526093  0.536534  2344.000000     0.543018
# weighted avg   0.710118  0.717577  0.711436  2344.000000     0.713828
# -------------------------------
#
# MariaDB
# -------------------------------
#               precision    recall  f1-score      support  fbeta-score
# Relate         0.727380  0.828648  0.774718  1494.000000     0.806200
# Block          0.737500  0.621053  0.674286   380.000000     0.622251
# Non-Link       0.790634  0.784153  0.787380   366.000000     0.784231
# Duplicate      0.381188  0.280000  0.322851   275.000000     0.280514
# Incorporate    0.776119  0.675325  0.722222   231.000000     0.675770
# Epic           0.948187  0.973404  0.960630   188.000000     0.973315
# Subtask        0.882353  0.842697  0.862069   178.000000     0.842813
# Cause          0.540741  0.419540  0.472492   174.000000     0.419800
# accuracy       0.730371  0.730371  0.730371     0.730371     0.730371
# macro avg      0.723013  0.678102  0.697081  3286.000000     0.699838
# weighted avg   0.721194  0.730371  0.722373  3286.000000     0.725754
# -------------------------------
#
# Mojang
# -------------------------------
#               precision    recall  f1-score      support  fbeta-score
# Duplicate      0.957990  0.978015  0.967899  38799.00000     0.967899
# Non-Link       0.966632  0.957550  0.962070   8622.00000     0.957794
# Relate         0.775254  0.636408  0.699003   4076.00000     0.637079
# accuracy       0.947550  0.947550  0.947550      0.94755     0.947550
# macro avg      0.899959  0.857325  0.876324  51497.00000     0.878124
# weighted avg   0.944974  0.947550  0.945640  51497.00000     0.946260
# -------------------------------
#
# MongoDB
# -------------------------------
#               precision    recall  f1-score       support  fbeta-score
# Relate         0.704356  0.761727  0.731919   5095.000000     0.755573
# Depend         0.696797  0.702548  0.699661   2787.000000     0.702325
# Epic           0.951613  0.987691  0.969316   2031.000000     0.986942
# Duplicate      0.518875  0.408033  0.456826   1718.000000     0.409378
# Non-Link       0.746851  0.696827  0.720973    851.000000     0.697009
# Documented     0.827869  0.830137  0.829001    365.000000     0.830135
# Cause          0.442748  0.267281  0.333333    217.000000     0.267309
# Subtask        0.871658  0.915730  0.893151    178.000000     0.915722
# Split          0.881481  0.793333  0.835088    150.000000     0.793343
# accuracy       0.730436  0.730436  0.730436      0.730436     0.730436
# macro avg      0.738028  0.707034  0.718808  13392.000000     0.722198
# weighted avg   0.722522  0.730436  0.724709  13392.000000     0.726458
# -------------------------------
#
# Qt
# -------------------------------
#               precision    recall  f1-score      support  fbeta-score
# Subtask        0.919781  0.941356  0.930444  1961.000000     0.940059
# Relate         0.522283  0.580089  0.549671  1798.000000     0.577630
# Depend         0.763069  0.722843  0.742412  1252.000000     0.723606
# Epic           0.949275  0.965009  0.957078  1086.000000     0.964763
# Duplicate      0.483099  0.404005  0.440026   849.000000     0.404661
# Non-Link       0.771631  0.813154  0.791849   669.000000     0.812897
# Split          0.508557  0.390244  0.441614   533.000000     0.390597
# Replace        0.470696  0.498062  0.483992   516.000000     0.497962
# accuracy       0.714912  0.714912  0.714912     0.714912     0.714912
# macro avg      0.673549  0.664345  0.667135  8664.000000     0.668916
# weighted avg   0.712066  0.714912  0.712170  8664.000000     0.713487
# -------------------------------
#
# RedHat
# -------------------------------
#               precision    recall  f1-score       support  fbeta-score
# Relate         0.592888  0.682954  0.634742   6201.000000     0.676906
# Subtask        0.884269  0.925592  0.904459   4986.000000     0.923931
# Clone          0.834572  0.850609  0.842514   3695.000000     0.850282
# Block          0.644464  0.606544  0.624929   3637.000000     0.607258
# Incorporate    0.782417  0.747186  0.764395   2132.000000     0.747418
# Duplicate      0.390649  0.218935  0.280607   1183.000000     0.219153
# Non-Link       0.733209  0.689474  0.710669   1140.000000     0.689558
# Follow         0.543257  0.416179  0.471302   1026.000000     0.416348
# Cause          0.455238  0.377567  0.412781    633.000000     0.377609
# accuracy       0.710551  0.710551  0.710551      0.710551     0.710551
# macro avg      0.651218  0.612782  0.627378  24633.000000     0.631416
# weighted avg   0.703316  0.710551  0.704270  24633.000000     0.706915
# -------------------------------
#
# Sakai
# -------------------------------
#               precision    recall  f1-score      support  fbeta-score
# Relate         0.678915  0.799176  0.734153  1942.000000     0.771832
# Subtask        0.904239  0.853333  0.878049   675.000000     0.854295
# Depend         0.534335  0.482558  0.507128   516.000000     0.483129
# Non-Link       0.798768  0.785859  0.792261   495.000000     0.786014
# Duplicate      0.538462  0.283784  0.371681   370.000000     0.284712
# Incorporate    0.615741  0.498127  0.550725   267.000000     0.498456
# Clone          0.672619  0.594737  0.631285   190.000000     0.594867
# accuracy       0.699663  0.699663  0.699663     0.699663     0.699663
# macro avg      0.677583  0.613939  0.637897  4455.000000     0.644193
# weighted avg   0.693906  0.699663  0.690632  4455.000000     0.696773
# -------------------------------
#
# SecondLife
# -------------------------------
#               precision    recall  f1-score     support  fbeta-score
# Subtask        0.850746  0.904762  0.876923   63.000000     0.893417
# Relate         0.675000  0.729730  0.701299   37.000000     0.726266
# Non-Link       0.826087  0.904762  0.863636   21.000000     0.903042
# Clone          0.571429  0.400000  0.470588   10.000000     0.400532
# Parent-Child   0.750000  0.375000  0.500000    8.000000     0.375578
# Depend         0.200000  0.166667  0.181818    6.000000     0.166711
# Incorporate    1.000000  0.666667  0.800000    3.000000     0.666759
# accuracy       0.763514  0.763514  0.763514    0.763514     0.763514
# macro avg      0.696180  0.592512  0.627752  148.000000     0.640177
# weighted avg   0.755636  0.763514  0.753563  148.000000     0.759554
# -------------------------------
#
# Sonatype
# -------------------------------
#                  precision    recall  f1-score     support  fbeta-score
# Relate            0.669312  0.708683  0.688435  357.000000     0.704539
# Subtask           0.923954  0.903346  0.913534  269.000000     0.904533
# Non-Link          0.802817  0.703704  0.750000   81.000000     0.704303
# Bonfire Testing   0.428571  0.416667  0.422535   72.000000     0.416735
# Duplicate         0.274194  0.250000  0.261538   68.000000     0.250112
# Cause             0.274510  0.297872  0.285714   47.000000     0.297815
# Depend            0.250000  0.281250  0.264706   32.000000     0.281211
# Supercede         0.217391  0.227273  0.222222   22.000000     0.227267
# Fix               0.266667  0.190476  0.222222   21.000000     0.190502
# accuracy          0.652219  0.652219  0.652219    0.652219     0.652219
# macro avg         0.456380  0.442141  0.447879  969.000000     0.449148
# weighted avg      0.653564  0.652219  0.652140  969.000000     0.652891
# -------------------------------
#
# Spring
# -------------------------------
#               precision    recall  f1-score      support  fbeta-score
# Relate         0.717089  0.820420  0.765282  1381.000000     0.797438
# Subtask        0.852332  0.847938  0.850129   388.000000     0.848005
# Depend         0.530547  0.471429  0.499244   350.000000     0.472070
# Duplicate      0.547085  0.349570  0.426573   349.000000     0.351116
# Epic           0.987805  0.990826  0.989313   327.000000     0.990796
# Non-Link       0.784431  0.816199  0.800000   321.000000     0.815872
# Supercede      0.428571  0.221053  0.291667    95.000000     0.221145
# accuracy       0.733728  0.733728  0.733728     0.733728     0.733728
# macro avg      0.692551  0.645348  0.660315  3211.000000     0.668117
# weighted avg   0.720385  0.733728  0.721996  3211.000000     0.726995
# -------------------------------

# %%
print('TLD results of TLDBERT')
for repo in REPOS:
    print(repo)
    print('-------------------------------')
    print(tb_cls_rep_d[repo])
    print('-------------------------------\n')
# Out:
# TLD results of TLDBERT
# Apache
# -------------------------------
#               precision    recall  f1-score       support  fbeta-score
# Subtask        0.898092  0.932446  0.914947  16757.000000     0.928893
# Relate         0.603103  0.714562  0.654119  14469.000000     0.706878
# Duplicate      0.574593  0.435294  0.495336   5185.000000     0.436341
# Block          0.583788  0.483478  0.528919   2875.000000     0.483734
# Epic           0.958545  0.980008  0.969158   2501.000000     0.979958
# Depend         0.531326  0.437600  0.479930   2500.000000     0.437775
# Non-Link       0.822711  0.788387  0.805183   2325.000000     0.788449
# Incorporate    0.619825  0.509344  0.559179   2087.000000     0.509489
# Breaks         0.388498  0.380460  0.384437    870.000000     0.380462
# Clone          0.682306  0.589120  0.632298    864.000000     0.589142
# Require        0.505660  0.370166  0.427432    724.000000     0.370185
# Supercede      0.422164  0.246154  0.310982    650.000000     0.246169
# Cause          0.375000  0.309179  0.338923    621.000000     0.309186
# accuracy       0.715496  0.715496  0.715496      0.715496     0.715496
# macro avg      0.612739  0.552015  0.576988  52428.000000     0.580794
# weighted avg   0.708899  0.715496  0.708605  52428.000000     0.712182
# -------------------------------
#
# Hyperledger
# -------------------------------
#               precision    recall  f1-score      support  fbeta-score
# Epic           0.964912  0.979102  0.971955  1292.000000     0.977664
# Subtask        0.889625  0.896552  0.893075   899.000000     0.896141
# Relate         0.691438  0.762923  0.725424   561.000000     0.761349
# Non-Link       0.834123  0.862745  0.848193   408.000000     0.862384
# Block          0.680851  0.594796  0.634921   269.000000     0.595177
# Duplicate      0.516667  0.242188  0.329787   128.000000     0.242340
# Clone          0.787879  0.821053  0.804124    95.000000     0.821029
# accuracy       0.854326  0.854326  0.854326     0.854326     0.854326
# macro avg      0.766499  0.737051  0.743925  3652.000000     0.751487
# weighted avg   0.848518  0.854326  0.849141  3652.000000     0.851412
# -------------------------------
#
# IntelDAOS
# -------------------------------
#               precision    recall  f1-score     support  fbeta-score
# Relate         0.642857  0.753695  0.693878  203.000000     0.740920
# Block          0.744000  0.699248  0.720930  133.000000     0.701731
# Subtask        0.822581  0.927273  0.871795   55.000000     0.926106
# Duplicate      0.416667  0.300000  0.348837   50.000000     0.300690
# Clone          0.944444  0.790698  0.860759   43.000000     0.791456
# Non-Link       0.625000  0.500000  0.555556   40.000000     0.500508
# finish-start   0.875000  0.700000  0.777778   20.000000     0.700178
# Verify         1.000000  0.875000  0.933333    8.000000     0.875023
# accuracy       0.701087  0.701087  0.701087    0.701087     0.701087
# macro avg      0.758819  0.693239  0.720358  552.000000     0.724548
# weighted avg   0.700432  0.701087  0.696356  552.000000     0.700759
# -------------------------------
#
# JFrog
# -------------------------------
#               precision    recall  f1-score     support  fbeta-score
# Subtask        0.939655  0.935622  0.937634  233.000000     0.936024
# Relate         0.601351  0.502825  0.547692  177.000000     0.507718
# Duplicate      0.487952  0.627907  0.549153  129.000000     0.621056
# Non-Link       0.769231  0.847458  0.806452   59.000000     0.846864
# Depend         0.428571  0.411765  0.420000   51.000000     0.411847
# Trigger        0.171429  0.150000  0.160000   40.000000     0.150065
# Incorporate    0.000000  0.000000  0.000000    9.000000     0.000000
# accuracy       0.666189  0.666189  0.666189    0.666189     0.666189
# macro avg      0.485456  0.496511  0.488704  698.000000     0.490921
# weighted avg   0.662498  0.666189  0.661392  698.000000     0.664338
# -------------------------------
#
# Jira
# -------------------------------
#               precision    recall  f1-score       support  fbeta-score
# Relate         0.869641  0.902145  0.885595  12682.000000     0.895451
# Duplicate      0.752105  0.698803  0.724475   4346.000000     0.700713
# Non-Link       0.896016  0.876426  0.886112   1052.000000     0.876479
# Clone          0.598116  0.664921  0.629752    573.000000     0.664864
# Subtask        0.952675  0.935354  0.943935    495.000000     0.935364
# Incorporate    0.657778  0.602851  0.629118    491.000000     0.602881
# Detail         0.917647  0.834225  0.873950    374.000000     0.834251
# Cause          0.474359  0.310924  0.375635    357.000000     0.310957
# accuracy       0.832744  0.832744  0.832744      0.832744     0.832744
# macro avg      0.764792  0.728206  0.743571  20370.000000     0.746051
# weighted avg   0.829153  0.832744  0.830134  20370.000000     0.830945
# -------------------------------
#
# JiraEcosystem
# -------------------------------
#               precision    recall  f1-score      support  fbeta-score
# Epic           0.971530  0.994536  0.982898   549.000000     0.993152
# Relate         0.556106  0.644359  0.596988   523.000000     0.638400
# Subtask        0.911111  0.897155  0.904079   457.000000     0.897684
# Duplicate      0.604457  0.623563  0.613861   348.000000     0.623169
# Block          0.529412  0.333333  0.409091   135.000000     0.333760
# Non-Link       0.689655  0.701754  0.695652   114.000000     0.701727
# Cause          0.397436  0.352273  0.373494    88.000000     0.352328
# Incorporate    0.346154  0.219512  0.268657    41.000000     0.219537
# Clone          0.615385  0.600000  0.607595    40.000000     0.600004
# Depend         0.357143  0.200000  0.256410    25.000000     0.200010
# Split          0.555556  0.208333  0.303030    24.000000     0.208347
# accuracy       0.729096  0.729096  0.729096     0.729096     0.729096
# macro avg      0.593995  0.524984  0.546523  2344.000000     0.557361
# weighted avg   0.724009  0.729096  0.723134  2344.000000     0.726543
# -------------------------------
#
# MariaDB
# -------------------------------
#               precision    recall  f1-score      support  fbeta-score
# Relate         0.738351  0.827309  0.780303  1494.000000     0.807843
# Block          0.717325  0.621053  0.665726   380.000000     0.622071
# Non-Link       0.755869  0.879781  0.813131   366.000000     0.878026
# Duplicate      0.454023  0.287273  0.351893   275.000000     0.288002
# Incorporate    0.725962  0.653680  0.687927   231.000000     0.654010
# Epic           0.978495  0.968085  0.973262   188.000000     0.968121
# Subtask        0.886905  0.837079  0.861272   178.000000     0.837223
# Cause          0.537190  0.373563  0.440678   174.000000     0.373878
# accuracy       0.736458  0.736458  0.736458     0.736458     0.736458
# macro avg      0.724265  0.680978  0.696774  3286.000000     0.701955
# weighted avg   0.724339  0.736458  0.725805  3286.000000     0.730348
# -------------------------------
#
# Mojang
# -------------------------------
#               precision    recall  f1-score       support  fbeta-score
# Duplicate      0.958227  0.977886  0.967957  38799.000000     0.967957
# Non-Link       0.973216  0.952447  0.962720   8622.000000     0.952997
# Relate         0.761836  0.647448  0.700000   4076.000000     0.648021
# accuracy       0.947473  0.947473  0.947473      0.947473     0.947473
# macro avg      0.897760  0.859261  0.876892  51497.000000     0.878088
# weighted avg   0.945192  0.947473  0.945871  51497.000000     0.946331
# -------------------------------
#
# MongoDB
# -------------------------------
#               precision    recall  f1-score       support  fbeta-score
# Relate         0.695295  0.797645  0.742962   5095.000000     0.786074
# Depend         0.727689  0.684607  0.705491   2787.000000     0.686170
# Epic           0.958733  0.983752  0.971081   2031.000000     0.983239
# Duplicate      0.532828  0.368452  0.435650   1718.000000     0.370209
# Non-Link       0.770060  0.755582  0.762752    851.000000     0.755637
# Documented     0.880597  0.808219  0.842857    365.000000     0.808268
# Cause          0.428571  0.304147  0.355795    217.000000     0.304170
# Subtask        0.858639  0.921348  0.888889    178.000000     0.921336
# Split          0.869565  0.800000  0.833333    150.000000     0.800008
# accuracy       0.738575  0.738575  0.738575      0.738575     0.738575
# macro avg      0.746886  0.713750  0.726535  13392.000000     0.729942
# weighted avg   0.730749  0.738575  0.730995  13392.000000     0.734641
# -------------------------------
#
# Qt
# -------------------------------
#               precision    recall  f1-score      support  fbeta-score
# Subtask        0.916667  0.947986  0.932063  1961.000000     0.946084
# Relate         0.544139  0.627364  0.582795  1798.000000     0.623695
# Depend         0.758065  0.750799  0.754414  1252.000000     0.750943
# Epic           0.945897  0.965930  0.955809  1086.000000     0.965615
# Duplicate      0.509537  0.440518  0.472521   849.000000     0.441110
# Non-Link       0.799710  0.823617  0.811487   669.000000     0.823473
# Split          0.575668  0.363977  0.445977   533.000000     0.364499
# Replace        0.495595  0.436047  0.463918   516.000000     0.436227
# accuracy       0.729455  0.729455  0.729455     0.729455     0.729455
# macro avg      0.693160  0.669530  0.677373  8664.000000     0.681140
# weighted avg   0.725121  0.729455  0.724760  8664.000000     0.727282
# -------------------------------
#
# RedHat
# -------------------------------
#               precision    recall  f1-score       support  fbeta-score
# Relate         0.603523  0.674085  0.636855   6201.000000     0.669481
# Subtask        0.911563  0.907541  0.909548   4986.000000     0.907695
# Clone          0.830990  0.847632  0.839228   3695.000000     0.847293
# Block          0.651224  0.614517  0.632338   3637.000000     0.615211
# Incorporate    0.769746  0.754221  0.761905   2132.000000     0.754326
# Duplicate      0.407634  0.225697  0.290533   1183.000000     0.225926
# Non-Link       0.795290  0.770175  0.782531   1140.000000     0.770226
# Follow         0.481076  0.470760  0.475862   1026.000000     0.470778
# Cause          0.389855  0.424961  0.406652    633.000000     0.424935
# accuracy       0.713555  0.713555  0.713555      0.713555     0.713555
# macro avg      0.648989  0.632177  0.637273  24633.000000     0.640472
# weighted avg   0.710300  0.713555  0.710052  24633.000000     0.711924
# -------------------------------
#
# Sakai
# -------------------------------
#               precision    recall  f1-score      support  fbeta-score
# Relate         0.690487  0.781153  0.733027  1942.000000     0.761164
# Subtask        0.870677  0.857778  0.864179   675.000000     0.858032
# Depend         0.517167  0.467054  0.490835   516.000000     0.467607
# Non-Link       0.768089  0.836364  0.800774   495.000000     0.835458
# Duplicate      0.454183  0.308108  0.367150   370.000000     0.308793
# Incorporate    0.716667  0.483146  0.577181   267.000000     0.483690
# Clone          0.713376  0.589474  0.645533   190.000000     0.589667
# accuracy       0.697194  0.697194  0.697194     0.697194     0.697194
# macro avg      0.675807  0.617582  0.639811  4455.000000     0.645384
# weighted avg   0.689256  0.697194  0.688915  4455.000000     0.693202
# -------------------------------
#
# SecondLife
# -------------------------------
#               precision    recall  f1-score     support  fbeta-score
# Subtask        0.855072  0.936508  0.893939   63.000000     0.919003
# Relate         0.695652  0.864865  0.771084   37.000000     0.852665
# Non-Link       0.850000  0.809524  0.829268   21.000000     0.810296
# Clone          0.750000  0.300000  0.428571   10.000000     0.300799
# Parent-Child   0.600000  0.375000  0.461538    8.000000     0.375433
# Depend         0.500000  0.166667  0.250000    6.000000     0.166844
# Incorporate    1.000000  0.666667  0.800000    3.000000     0.666759
# accuracy       0.790541  0.790541  0.790541    0.790541     0.790541
# macro avg      0.750104  0.588461  0.633486  148.000000     0.659523
# weighted avg   0.782153  0.790541  0.771223  148.000000     0.786325
# -------------------------------
#
# Sonatype
# -------------------------------
#                  precision    recall  f1-score     support  fbeta-score
# Relate            0.657895  0.700280  0.678426  357.000000     0.695797
# Subtask           0.921053  0.910781  0.915888  269.000000     0.911379
# Non-Link          0.800000  0.839506  0.819277   81.000000     0.839220
# Bonfire Testing   0.493333  0.513889  0.503401   72.000000     0.513763
# Duplicate         0.311475  0.279412  0.294574   68.000000     0.279558
# Cause             0.260000  0.276596  0.268041   47.000000     0.276556
# Depend            0.500000  0.375000  0.428571   32.000000     0.375104
# Supercede         0.571429  0.181818  0.275862   22.000000     0.181882
# Fix               0.238095  0.238095  0.238095   21.000000     0.238095
# accuracy          0.673891  0.673891  0.673891    0.673891     0.673891
# macro avg         0.528142  0.479486  0.491348  969.000000     0.502640
# weighted avg      0.670716  0.673891  0.669340  969.000000     0.672299
# -------------------------------
#
# Spring
# -------------------------------
#               precision    recall  f1-score      support  fbeta-score
# Relate         0.733639  0.811731  0.770712  1381.000000     0.794810
# Subtask        0.875000  0.865979  0.870466   388.000000     0.866117
# Depend         0.535503  0.517143  0.526163   350.000000     0.517359
# Duplicate      0.514286  0.412607  0.457870   349.000000     0.413605
# Epic           0.981873  0.993884  0.987842   327.000000     0.993763
# Non-Link       0.851852  0.788162  0.818770   321.000000     0.788746
# Supercede      0.528302  0.294737  0.378378    95.000000     0.294850
# accuracy       0.743694  0.743694  0.743694     0.743694     0.743694
# macro avg      0.717208  0.669178  0.687172  3211.000000     0.692361
# weighted avg   0.736304  0.743694  0.737416  3211.000000     0.739980
# -------------------------------

# %%
repo_overview = pd.read_csv('./data/repo_overview.csv', encoding='UTF-8', low_memory=False, sep=',', index_col=0)
repo_overview.drop(index=['Mindville'], inplace=True)
repo_overview
# Out:
#                Year  #Issues  #Comments  #Links  #Linktypes  #Projects  \
# Apache         2000  1014926    4608221  255767          16        646
# Hyperledger    2016    28146      44590   16304           8         32
# IntelDAOS      2016     9474      32203    2599          11          2
# JFrog          2006    15535      13152    3229          10         10
# Jira           2002   274545     779104   99819          16         30
# JiraEcosystem  2004    41866      68387   11398          14        101
# MariaDB        2009    31229          0   14618           8         11
# Mojang         2012   420819     933348  215527           5          8
# MongoDB        2009   137172     368976   63821          14         27
# Qt             2005   148579     421771   40105          11         21
# RedHat         2001   353000     859880  119669          15        241
# Sakai          2004    50550     180191   19803           8         53
# SecondLife     2007     1867      15728     631           6          2
# Sonatype       2008    87284     339127    4465          11          5
# Spring         2003    69156     186077   14462           7         80
#
#                %IssuesWithLinks  %CrossProject
# Apache                     28.5           5.23
# Hyperledger                54.9           4.62
# IntelDAOS                  30.8           3.27
# JFrog                      28.6           8.24
# Jira                       46.7          43.42
# JiraEcosystem              33.0           6.77
# MariaDB                    44.5           2.54
# Mojang                     53.7           5.43
# MongoDB                    45.2          19.09
# Qt                         30.2           6.92
# RedHat                     39.2          23.54
# Sakai                      42.4           1.37
# SecondLife                 39.9           2.38
# Sonatype                    7.0           1.50
# Spring                     25.6           9.96

# %%
# Different Types of Users in issue trackers
user_numbers = pd.read_csv('./data/user_numbers.csv', encoding='UTF-8', low_memory=False, sep=',', index_col=0)
user_numbers.drop(index = ['Mindville'], inplace=True)
user_numbers['Ages'] = 2023 - repo_overview['Year']
user_numbers
# Out:
#                TotalUsers  Creators  Reporters  Assignees  LinkSetters  Ages
# Apache             115394    112718     113477      17513        11020    23
# Hyperledger          1805      1638       1643        913          329     7
# IntelDAOS              85        77         77         76           51     7
# JFrog                2713      2677       2664        182          303    17
# Jira                50930     41325      50203       2143         6300    21
# JiraEcosystem        4166      3918       4006        786          760    19
# MariaDB              4229      4216       4220        133          490    14
# Mojang             242589    242506     242240         79          339    11
# MongoDB              7777      7655       7680        646          929    14
# Qt                  21386     21189      21173       1347          614    18
# RedHat              17698     17288      17365       2616         2685    22
# Sakai                1584      1441       1462        696          378    19
# SecondLife            341       332        327         95          194    16
# Sonatype            45651     45595      45626         90         1004    15
# Spring              15222     15188      15189        260          121    20

# %%
repo_overview = repo_overview.transpose()
repo_overview
# Out:
#                       Apache  Hyperledger  IntelDAOS     JFrog       Jira  \
# Year                 2000.00      2016.00    2016.00   2006.00    2002.00
# #Issues           1014926.00     28146.00    9474.00  15535.00  274545.00
# #Comments         4608221.00     44590.00   32203.00  13152.00  779104.00
# #Links             255767.00     16304.00    2599.00   3229.00   99819.00
# #Linktypes             16.00         8.00      11.00     10.00      16.00
# #Projects             646.00        32.00       2.00     10.00      30.00
# %IssuesWithLinks       28.50        54.90      30.80     28.60      46.70
# %CrossProject           5.23         4.62       3.27      8.24      43.42
#
#                   JiraEcosystem   MariaDB     Mojang    MongoDB         Qt  \
# Year                    2004.00   2009.00    2012.00    2009.00    2005.00
# #Issues                41866.00  31229.00  420819.00  137172.00  148579.00
# #Comments              68387.00      0.00  933348.00  368976.00  421771.00
# #Links                 11398.00  14618.00  215527.00   63821.00   40105.00
# #Linktypes                14.00      8.00       5.00      14.00      11.00
# #Projects                101.00     11.00       8.00      27.00      21.00
# %IssuesWithLinks          33.00     44.50      53.70      45.20      30.20
# %CrossProject              6.77      2.54       5.43      19.09       6.92
#
#                      RedHat      Sakai  SecondLife  Sonatype     Spring
# Year                2001.00    2004.00     2007.00    2008.0    2003.00
# #Issues           353000.00   50550.00     1867.00   87284.0   69156.00
# #Comments         859880.00  180191.00    15728.00  339127.0  186077.00
# #Links            119669.00   19803.00      631.00    4465.0   14462.00
# #Linktypes            15.00       8.00        6.00      11.0       7.00
# #Projects            241.00      53.00        2.00       5.0      80.00
# %IssuesWithLinks      39.20      42.40       39.90       7.0      25.60
# %CrossProject         23.54       1.37        2.38       1.5       9.96

# %%
user_num = user_numbers.transpose()
user_num
# Out:
#              Apache  Hyperledger  IntelDAOS  JFrog   Jira  JiraEcosystem  \
# TotalUsers   115394         1805         85   2713  50930           4166
# Creators     112718         1638         77   2677  41325           3918
# Reporters    113477         1643         77   2664  50203           4006
# Assignees     17513          913         76    182   2143            786
# LinkSetters   11020          329         51    303   6300            760
# Ages             23            7          7     17     21             19
#
#              MariaDB  Mojang  MongoDB     Qt  RedHat  Sakai  SecondLife  \
# TotalUsers      4229  242589     7777  21386   17698   1584         341
# Creators        4216  242506     7655  21189   17288   1441         332
# Reporters       4220  242240     7680  21173   17365   1462         327
# Assignees        133      79      646   1347    2616    696          95
# LinkSetters      490     339      929    614    2685    378         194
# Ages              14      11       14     18      22     19          16
#
#              Sonatype  Spring
# TotalUsers      45651   15222
# Creators        45595   15188
# Reporters       45626   15189
# Assignees          90     260
# LinkSetters      1004     121
# Ages               15      20

# %%
# Get different attributes of repositories
repos = []
bert_acc = []       # bert accuracy
tb_acc = []         # tldbert accuracy
bert_mf = []        # bert macro f1-score
tb_mf = []          # tldbert macro f1-score

num_issues = []
num_comms = []
num_links = []
num_linktypes = []  # documented link types
num_predlts = []    # predicted link types
num_projs = []
coverage = []       # %Cov.
crossproject = []   # %CP

num_totalusers = []
age = []

for repo in REPOS:
    cls_rep_df = cls_rep_d[repo]
    tb_cls_rep_df = tb_cls_rep_d[repo]
    
    repos.append(repo)

    bert_acc.append(cls_rep_df['f1-score'].loc['accuracy'])
    tb_acc.append(tb_cls_rep_df['f1-score'].loc['accuracy'])

    bert_mf.append(cls_rep_df['f1-score'].loc['macro avg'])
    tb_mf.append(tb_cls_rep_df['f1-score'].loc['macro avg'])
    
    num_issues.append(repo_overview.loc['#Issues'][repo])
    num_comms.append(repo_overview.loc['#Comments'][repo])
    num_links.append(repo_overview.loc['#Links'][repo])
    num_linktypes.append(repo_overview.loc['#Linktypes'][repo])
    num_projs.append(repo_overview.loc['#Projects'][repo])
    coverage.append(repo_overview.loc['%IssuesWithLinks'][repo])
    crossproject.append(repo_overview.loc['%CrossProject'][repo])

    num_totalusers.append(user_num.loc['TotalUsers'][repo])
    age.append(user_num.loc['Ages'][repo])
    
    filename = './data/joined/links_plus/' + repo + '.csv'
    links = pd.read_csv(filename, encoding='UTF-8', low_memory=False, sep=';', usecols=['linktype', 'issue_id_1', 'issue_id_2'])
    
    links['mappedtype'] = links['linktype'].map(fine_linktype_map)
    linktypes = (links.mappedtype.value_counts() >= len(links) * 0.01).rename_axis('mappedtype').reset_index(name='valid')
    valid_types = set(linktypes[linktypes['valid'] == True]['mappedtype'])

    num_predlts.append(len(valid_types) + 1)  # add Non-Link type

stat_dict = {
    'repos': repos,
    'bert_acc': bert_acc,
    'tb_acc': tb_acc,
    'bert_mf': bert_mf,
    'tb_mf': tb_mf, 
    'num_issues': num_issues,
    'num_comms': num_comms, 
    'num_links' : num_links,
    'num_linktypes': num_linktypes,
    'num_predlts': num_predlts,
    'num_projs': num_projs,
    'norm_projs': np.array(num_projs) / np.linalg.norm(np.array(num_projs)),
    'coverage': coverage,
    'crossproject': crossproject,
    'num_totalusers': num_totalusers,
    'age': age
    }

stat_df = pd.DataFrame(stat_dict)

# %%
# Calculate issue-user ratios
stat_df['issue_user_ratio'] = stat_df['num_issues'] / stat_df['num_totalusers']

stat_df['acc_delta'] = stat_df['tb_acc'] - stat_df['bert_acc']
stat_df['acc_re'] = (stat_df['acc_delta'] / stat_df['bert_acc'])

stat_df['mf_delta'] = stat_df['tb_mf'] - stat_df['bert_mf']
stat_df['mf_re'] = (stat_df['mf_delta'] / stat_df['bert_mf'])

# %%
stat_df.sort_values(by='repos')
# Out:
#             repos  bert_acc    tb_acc   bert_mf     tb_mf  num_issues  \
# 0          Apache  0.702373  0.715496  0.554467  0.576988   1014926.0
# 1     Hyperledger  0.844469  0.854326  0.731951  0.743925     28146.0
# 2       IntelDAOS  0.657609  0.701087  0.686222  0.720358      9474.0
# 3           JFrog  0.647564  0.666189  0.486652  0.488704     15535.0
# 4            Jira  0.825086  0.832744  0.727519  0.743571    274545.0
# 5   JiraEcosystem  0.717577  0.729096  0.536534  0.546523     41866.0
# 6         MariaDB  0.730371  0.736458  0.697081  0.696774     31229.0
# 7          Mojang  0.947550  0.947473  0.876324  0.876892    420819.0
# 8         MongoDB  0.730436  0.738575  0.718808  0.726535    137172.0
# 9              Qt  0.714912  0.729455  0.667135  0.677373    148579.0
# 10         RedHat  0.710551  0.713555  0.627378  0.637273    353000.0
# 11          Sakai  0.699663  0.697194  0.637897  0.639811     50550.0
# 12     SecondLife  0.763514  0.790541  0.627752  0.633486      1867.0
# 13       Sonatype  0.652219  0.673891  0.447879  0.491348     87284.0
# 14         Spring  0.733728  0.743694  0.660315  0.687172     69156.0
#
#     num_comms  num_links  num_linktypes  num_predlts  ...  norm_projs  \
# 0   4608221.0   255767.0           16.0           13  ...    0.915213
# 1     44590.0    16304.0            8.0            7  ...    0.045336
# 2     32203.0     2599.0           11.0            8  ...    0.002833
# 3     13152.0     3229.0           10.0            7  ...    0.014167
# 4    779104.0    99819.0           16.0            8  ...    0.042502
# 5     68387.0    11398.0           14.0           11  ...    0.143091
# 6         0.0    14618.0            8.0            8  ...    0.015584
# 7    933348.0   215527.0            5.0            3  ...    0.011334
# 8    368976.0    63821.0           14.0            9  ...    0.038252
# 9    421771.0    40105.0           11.0            8  ...    0.029752
# 10   859880.0   119669.0           15.0            9  ...    0.341434
# 11   180191.0    19803.0            8.0            7  ...    0.075087
# 12    15728.0      631.0            6.0            7  ...    0.002833
# 13   339127.0     4465.0           11.0            9  ...    0.007084
# 14   186077.0    14462.0            7.0            7  ...    0.113339
#
#     coverage  crossproject  num_totalusers  age  issue_user_ratio  acc_delta  \
# 0       28.5          5.23          115394   23          8.795310   0.013123
# 1       54.9          4.62            1805    7         15.593352   0.009858
# 2       30.8          3.27              85    7        111.458824   0.043478
# 3       28.6          8.24            2713   17          5.726133   0.018625
# 4       46.7         43.42           50930   21          5.390634   0.007658
# 5       33.0          6.77            4166   19         10.049448   0.011519
# 6       44.5          2.54            4229   14          7.384488   0.006086
# 7       53.7          5.43          242589   11          1.734699  -0.000078
# 8       45.2         19.09            7777   14         17.638164   0.008139
# 9       30.2          6.92           21386   18          6.947489   0.014543
# 10      39.2         23.54           17698   22         19.945757   0.003004
# 11      42.4          1.37            1584   19         31.912879  -0.002469
# 12      39.9          2.38             341   16          5.475073   0.027027
# 13       7.0          1.50           45651   15          1.911984   0.021672
# 14      25.6          9.96           15222   20          4.543161   0.009966
#
#       acc_re  mf_delta     mf_re
# 0   0.018683  0.022521  0.040618
# 1   0.011673  0.011974  0.016359
# 2   0.066116  0.034136  0.049745
# 3   0.028761  0.002053  0.004218
# 4   0.009282  0.016052  0.022065
# 5   0.016052  0.009989  0.018618
# 6   0.008333 -0.000307 -0.000440
# 7  -0.000082  0.000568  0.000649
# 8   0.011143  0.007727  0.010750
# 9   0.020342  0.010237  0.015345
# 10  0.004228  0.009895  0.015772
# 11 -0.003529  0.001914  0.003000
# 12  0.035398  0.005734  0.009134
# 13  0.033228  0.043470  0.097057
# 14  0.013582  0.026856  0.040672
#
# [15 rows x 21 columns]

# %%
print('Statistical significance of accuracy increase')
print(stats.ttest_rel(stat_df['bert_acc'], stat_df['tb_acc']))
# Out:
# Statistical significance of accuracy increase
# TtestResult(statistic=-4.297568321369522, pvalue=0.0007370030015306789, df=14)

# %%
print('Statistical significance of macro F1-score increase')
print(stats.ttest_rel(stat_df['bert_mf'], stat_df['tb_mf']))
# Out:
# Statistical significance of macro F1-score increase
# TtestResult(statistic=-4.045957046265094, pvalue=0.0012027326106615836, df=14)

# %%
print('Number and median of predicted link types (>1%)')
print(stat_df['num_predlts'], stat_df['num_predlts'].median())
# Out:
# Number and median of predicted link types (>1%)
# 0     13
# 1      7
# 2      8
# 3      7
# 4      8
# 5     11
# 6      8
# 7      3
# 8      9
# 9      8
# 10     9
# 11     7
# 12     7
# 13     9
# 14     7
# Name: num_predlts, dtype: int64 8.0

# %%
acc_re = stat_df['acc_re'].apply(lambda x : format(x, '.1%'))
mf_re = stat_df['mf_re'].apply(lambda x : format(x, '.1%'))

# %%
print('Relative increase of accuracy')
print(acc_re)
# Out:
# Relative increase of accuracy
# 0      1.9%
# 1      1.2%
# 2      6.6%
# 3      2.9%
# 4      0.9%
# 5      1.6%
# 6      0.8%
# 7     -0.0%
# 8      1.1%
# 9      2.0%
# 10     0.4%
# 11    -0.4%
# 12     3.5%
# 13     3.3%
# 14     1.4%
# Name: acc_re, dtype: object

# %%
print('Relative increase of macro F1-score')
print(mf_re)
# Out:
# Relative increase of macro F1-score
# 0      4.1%
# 1      1.6%
# 2      5.0%
# 3      0.4%
# 4      2.2%
# 5      1.9%
# 6     -0.0%
# 7      0.1%
# 8      1.1%
# 9      1.5%
# 10     1.6%
# 11     0.3%
# 12     0.9%
# 13     9.7%
# 14     4.1%
# Name: mf_re, dtype: object

# %%
print('Caculate Pearson correlation')
for i in ['acc_delta', 'mf_delta']:
    print(i)
    for j in ['num_issues', 'num_comms', 'num_links', 'num_linktypes', 'num_predlts', 'num_projs', 'norm_projs', 'coverage', 'crossproject', 'num_totalusers', 'issue_user_ratio', 'age']:
        print(j)
        r = stats.pearsonr(stat_df[i], stat_df[j])
        print(np.round(r, 4))
    print('-------------------------------------')
# Out:
# Caculate Pearson correlation
# acc_delta
# num_issues
# [-0.2447  0.3793]
# num_comms
# [-0.1243  0.659 ]
# num_links
# [-0.3811  0.161 ]
# num_linktypes
# [0.0091 0.9744]
# num_predlts
# [0.1629 0.5619]
# num_projs
# [-0.1353  0.6308]
# norm_projs
# [-0.1353  0.6308]
# coverage
# [-0.4771  0.0722]
# crossproject
# [-0.2706  0.3293]
# num_totalusers
# [-0.3051  0.2688]
# issue_user_ratio
# [0.5935 0.0197]
# age
# [-0.3808  0.1614]
# -------------------------------------
# mf_delta
# num_issues
# [0.0861 0.7602]
# num_comms
# [0.1686 0.5481]
# num_links
# [-0.0911  0.7468]
# num_linktypes
# [0.2578 0.3535]
# num_predlts
# [0.3502 0.2006]
# num_projs
# [0.1533 0.5855]
# norm_projs
# [0.1533 0.5855]
# coverage
# [-0.7093  0.0031]
# crossproject
# [-0.0401  0.8871]
# num_totalusers
# [-0.0603  0.8308]
# issue_user_ratio
# [0.3325 0.226 ]
# age
# [-0.0598  0.8323]
# -------------------------------------
